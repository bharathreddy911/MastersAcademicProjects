# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("aerofit_treadmill.csv")

# %%
df.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   KP281   18    Male         14        Single      3        4   29562    112
# 1   KP281   19    Male         15        Single      2        3   31836     75
# 2   KP281   19  Female         14     Partnered      4        3   30699     66
# 3   KP281   19    Male         12        Single      3        3   32973     85
# 4   KP281   20    Male         13     Partnered      4        2   35247     47

# %%
df.shape
# Out:
# (180, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
df['Product'].unique()
# Out:
# array(['KP281', 'KP481', 'KP781'], dtype=object)

# %%
df.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   KP281   18    Male         14        Single      3        4   29562    112
# 1   KP281   19    Male         15        Single      2        3   31836     75
# 2   KP281   19  Female         14     Partnered      4        3   30699     66
# 3   KP281   19    Male         12        Single      3        3   32973     85
# 4   KP281   20    Male         13     Partnered      4        2   35247     47

# %%
sns.histplot(data=df, x="Age",bins=20,kde=True)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
sns.displot(data=df, x="Age",bins=20,kde=True)

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Product',data=df,hue='Usage',dodge=False)
# Out:
# <AxesSubplot:xlabel='Product', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x='MaritalStatus',y='Income',data=df,showmeans=True)
# Out:
# <AxesSubplot:xlabel='MaritalStatus', ylabel='Income'>

# %%
# The KP281 is an entry-level treadmill that sells for $1,500.
# The KP481 is for mid-level runners that sns.countplot(x='MaritalStatus',hue='Education',data=df,dodge=False)
plt.legend( loc=(1.2,0.2))sell for $1,750.
# The KP781 treadmill is having advanced features that sell for $2,500.

# %%
df.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   KP281   18    Male         14        Single      3        4   29562    112
# 1   KP281   19    Male         15        Single      2        3   31836     75
# 2   KP281   19  Female         14     Partnered      4        3   30699     66
# 3   KP281   19    Male         12        Single      3        3   32973     85
# 4   KP281   20    Male         13     Partnered      4        2   35247     47

# %%
df.groupby(['MaritalStatus'])['Age'].describe()
# Out:
#                count       mean       std   min   25%   50%   75%   max
# MaritalStatus
# Partnered      107.0  29.887850  7.250670  19.0  25.0  28.0  34.5  50.0
# Single          73.0  27.178082  6.167438  18.0  23.0  25.0  31.0  45.0

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Age',data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
df.nunique()
# Out:
# Product           3
# Age              32
# Gender            2
# Education         8
# MaritalStatus     2
# Usage             6
# Fitness           5
# Income           62
# Miles            37
# dtype: int64

# %%
sns.pairplot(data=df,diag_kind='kde')

# %%
sns.heatmap(df.corr()
#          ,vmin=-1
           ,vmax=1
           ,center=0
           ,cmap='OrRd_r'
           ,annot=True
           ,fmt='.1f'
           ,annot_kws=dict(size=15,weight='bold')
           ,linecolor='black'
           ,linewidths=0.5)
# Out:
# <AxesSubplot:>

# %%
df_plot = df.groupby(['Product', 'Fitness']).size().reset_index().pivot(columns='Fitness', index='Product', values=0)

# %%
df_plot.plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot:xlabel='Product'>
